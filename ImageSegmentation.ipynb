# %% [markdown]
# <a href="https://colab.research.google.com/github/badrinarayanan02/DataAnalytics/blob/main/ImageSegmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Image Segmentation

# %% [markdown]
# ## Thresholding

# %%
from google.colab.patches import cv2_imshow
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread('/content/download (3).jpeg', cv2.IMREAD_GRAYSCALE)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=304x166>

# %%
ret,thresh1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
ret,thresh2 = cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)
ret,thresh3 = cv2.threshold(img,127,255,cv2.THRESH_TRUNC)
ret,thresh4 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO)
ret,thresh5 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO_INV)

# %%
title = ['Original Img', 'T1', 'T2', 'T3', 'T4','T5']
images = [img,thresh1,thresh2,thresh3,thresh4,thresh5]

for i in range(6):
   plt.subplot(2,3,i+1),plt.imshow(images[i],'gray',vmin=0,vmax=255)
   plt.title(title[i])
   plt.xticks([]),plt.yticks([])
plt.show()

# %% [markdown]
# ## Watershed Algorithm

# %%
ballsimg = cv2.imread('/content/sample.png',cv2.IMREAD_GRAYSCALE)
cv2_imshow(ballsimg)
# Out:
# <PIL.Image.Image image mode=L size=219x252>

# %%
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
bin_img = cv2.morphologyEx(ballsimg,
                           cv2.MORPH_OPEN,
                           kernel,
                           iterations=2)
cv2_imshow(bin_img)
# Out:
# <PIL.Image.Image image mode=L size=219x252>
